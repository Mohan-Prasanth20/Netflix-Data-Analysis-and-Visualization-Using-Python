# %% [markdown]
# # Netfilx Data Analysis

# %% [raw]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing dataset

Data = pd.read_csv('netflix1.csv')

# %% [raw]
# # Data Overview

# %%
Data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
Data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
Data.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
 Data.shape
# Out:
# (8790, 10)

# %%
Data.isnull().count()
# Out:
# show_id         8790
# type            8790
# title           8790
# director        8790
# country         8790
# date_added      8790
# release_year    8790
# rating          8790
# duration        8790
# listed_in       8790
# dtype: int64

# %% [raw]
# # Data Cleansing

# %%
#Imputing missing values

Data.show_id.fillna("show_id unavailable", inplace=True)
Data.country.fillna("country unavailable", inplace=True)
Data.director.fillna("director unavailable", inplace=True)

# %%
Data.dropna(subset=["release_date", "rating", "duration", "title"], inplace=True)
Data.drop(["date_added"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 Data.dropna(subset=["release_date", "rating", "duration", "title"], inplace=True)
#       2 Data.drop(["date_added"], axis=1, inplace=True)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:6553, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6551     check = indices == -1
#    6552     if check.any():
# ...

# %%
#Dataset information

Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
Data.duplicated().value_counts()
# Out:
# False    8790
# dtype: int64

# %%
Data['director'].head()
# Out:
# 0    Kirsten Johnson
# 1    Julien Leclercq
# 2      Mike Flanagan
# 3      Bruno Garotti
# 4       Haile Gerima
# Name: director, dtype: object

# %%
Data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
#removed all duplicates
# dropped ALL duplicate values

Data.drop_duplicates()
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [raw]
# # Exploratory Data Analysis and Visualization

# %%
Countries = Data.set_index('title').production_country.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
Countries = Countries[Countries != 'production country unavailable']
plt.figure(figsize=(10,8))
g = sns.countplot(x = Countries, order=Countries.value_counts().index[:10], palette='dark:salmon')
plt.title('Top 10 Content Producing Countries', fontsize=21)
plt.xlabel('Country')
plt.ylabel('Titles')
plt.show()

# %%
#types of show on netflix
types =Data.groupby(['type',])[ 'type'].count().reset_index(name='count')
types=types.set_index('type')
types

# %%
types.plot.pie(y='count',autopct='%.1f%%', shadow=True, legend= 'type')
plt.title('types_of_show', fontsize=10)

# %%
Data.loc[Data['country']=='India'].head(10)
# Out:
#     show_id   type                            title              director  \
# 7      s939  Movie  Motu Patlu in the Game of Zones           Suhas Kadav
# 9      s940  Movie         Motu Patlu in Wonderland           Suhas Kadav
# 10     s941  Movie   Motu Patlu: Deep Sea Adventure           Suhas Kadav
# 11     s942  Movie         Motu Patlu: Mission Moon           Suhas Kadav
# 29      s25  Movie                            Jeans            S. Shankar
# 51      s27  Movie                   Minsara Kanavu           Rajiv Menon
# 142    s106  Movie                 Angamaly Diaries  Lijo Jose Pellissery
# 148    s115  Movie                           Anjaam          Rahul Rawail
# 170    s117  Movie                           Dhanak       Nagesh Kukunoor
# 172    s119  Movie                          Gurgaon         Shanker Raman
#
#     country date_added  release_year rating duration  \
# 7     India   5/1/2021          2019  TV-Y7   87 min
# ...

# %%
for i in Data.columns:
# Out:
#   Cell In [17], line 1
#     for i in Data.columns:
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
Data['country'] = Data['country'].fillna(Data['country'].mode()[0])
Data['director'].replace(np.nan,'No data',inplace=True)
Data.dropna(inplace=True)
Data.drop_duplicates(inplace=True)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 755.4+ KB

# %%
Data['country'].replace('United States', 'USA', inplace=True)
Data['country'].replace('United Kingdom', 'UK',inplace=True)
Data['country'].replace('South Korea', 'S. Korea',inplace=True)

# %%
Data['count']=1 #helper column
df = Data.groupby('country')['count'].sum().sort_values(ascending=False)[:10]
df
# Out:
# country
# USA          3240
# India        1057
# UK            638
# Pakistan      421
# Not Given     287
# Canada        271
# Japan         259
# S. Korea      214
# France        213
# Spain         182
# Name: count, dtype: int64
